# %% [markdown]
# <a href="https://colab.research.google.com/github/aurore-pouchain/landing/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as mp
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-efd399ff-c510-44c1-8993-d21315121762" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-efd399ff-c510-44c1-8993-d21315121762">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('projet csv sans.csv')

# %%
df.head()
# Out:
#        Date  Wheat Adj Close  US oil price (WTI)  Papa John's Adj. Close  \
# 0       NaN              NaN                 NaN                     NaN
# 1  1/3/2017           406.50               52.33                   78.14
# 2  1/4/2017           418.50               53.26                   79.15
# 3  1/5/2017           426.25               53.76                   79.59
# 4  1/6/2017           423.25               53.99                   78.97
#
#    Av. adj close according to the period Quarantine variable
# 0                                    NaN                 NaN
# 1                                 158.55                  no
# 2                                 158.55                  no
# 3                                 158.55                  no
# 4                                 158.55                  no

# %%
df.isnull().sum().sum()
# Out:
# 6

# %%
df.dropna()
# Out:
#             Date  Wheat Adj Close  US oil price (WTI)  Papa John's Adj. Close  \
# 1       1/3/2017           406.50               52.33                   78.14
# 2       1/4/2017           418.50               53.26                   79.15
# 3       1/5/2017           426.25               53.76                   79.59
# 4       1/6/2017           423.25               53.99                   78.97
# 5       1/9/2017           427.25               51.96                   78.28
# ...          ...              ...                 ...                     ...
# 1254  12/23/2021           814.75               73.79                  130.33
# 1255  12/27/2021           804.00               75.57                  132.32
# 1256  12/28/2021           783.50               75.98                  131.76
# 1257  12/29/2021           787.75               76.56                  135.57
# 1258  12/30/2021           779.75               76.99                  132.38
#
# ...

# %%
df.isnull().sum()
# Out:
# Date                                     1
# Wheat Adj Close                          1
# US oil price (WTI)                       1
# Papa John's Adj. Close                   1
# Av. adj close according to the period    1
# Quarantine variable                      1
# dtype: int64

# %%
df.isnull().sum(axis=0)
# Out:
# Date                                     1
# Wheat Adj Close                          1
# US oil price (WTI)                       1
# Papa John's Adj. Close                   1
# Av. adj close according to the period    1
# Quarantine variable                      1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#             Date  Wheat Adj Close  US oil price (WTI)  Papa John's Adj. Close  \
# 1       1/3/2017           406.50               52.33                   78.14
# 2       1/4/2017           418.50               53.26                   79.15
# 3       1/5/2017           426.25               53.76                   79.59
# 4       1/6/2017           423.25               53.99                   78.97
# 5       1/9/2017           427.25               51.96                   78.28
# ...          ...              ...                 ...                     ...
# 1254  12/23/2021           814.75               73.79                  130.33
# 1255  12/27/2021           804.00               75.57                  132.32
# 1256  12/28/2021           783.50               75.98                  131.76
# 1257  12/29/2021           787.75               76.56                  135.57
# 1258  12/30/2021           779.75               76.99                  132.38
#
# ...

# %%
df.dropna(axis=0)
# Out:
#             Date  Wheat Adj Close  US oil price (WTI)  Papa John's Adj. Close  \
# 1       1/3/2017           406.50               52.33                   78.14
# 2       1/4/2017           418.50               53.26                   79.15
# 3       1/5/2017           426.25               53.76                   79.59
# 4       1/6/2017           423.25               53.99                   78.97
# 5       1/9/2017           427.25               51.96                   78.28
# ...          ...              ...                 ...                     ...
# 1254  12/23/2021           814.75               73.79                  130.33
# 1255  12/27/2021           804.00               75.57                  132.32
# 1256  12/28/2021           783.50               75.98                  131.76
# 1257  12/29/2021           787.75               76.56                  135.57
# 1258  12/30/2021           779.75               76.99                  132.38
#
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1258 entries, 1 to 1258
# Data columns (total 6 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Date                                   1258 non-null   object
#  1   Wheat Adj Close                        1258 non-null   float64
#  2   US oil price (WTI)                     1258 non-null   float64
#  3   Papa John's Adj. Close                 1258 non-null   float64
#  4   Av. adj close according to the period  1258 non-null   float64
#  5   Quarantine variable                    1258 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.8+ KB

# %%
df['Quarantine variable'] = df['Quarantine variable'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1258 entries, 1 to 1258
# Data columns (total 6 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Date                                   1258 non-null   object
#  1   Wheat Adj Close                        1258 non-null   float64
#  2   US oil price (WTI)                     1258 non-null   float64
#  3   Papa John's Adj. Close                 1258 non-null   float64
#  4   Av. adj close according to the period  1258 non-null   float64
#  5   Quarantine variable                    1258 non-null   category
# dtypes: category(1), float64(4), object(1)
# memory usage: 60.3+ KB

# %%
pd.get_dummies(df['Quarantine variable']).head()
# Out:
#    no  yes
# 1   1    0
# 2   1    0
# 3   1    0
# 4   1    0
# 5   1    0

# %%
quar = pd.get_dummies(df['Quarantine variable']), drop_first=True)
# Out:
#   File "<ipython-input-24-a1eb08ac29d6>", line 1
#     quar = pd.get_dummies(df['Quarantine variable']), drop_first=True)
#                                                                      ^
# SyntaxError: invalid syntax
